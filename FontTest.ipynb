# %% [markdown]
# # Set up the font as "IPAPGothic"

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.font_manager import FontProperties
fp = FontProperties(fname=r'/Users/aa373282/Documents/Python/ProjectJJ/ipagp.ttf', size=14)

#plt.rcParams['font.family'] = 'IPAGothic' #全体のフォントを設定
#plt.rcParams["font.family"] = "IPAPGothic"
font = {'family': 'ipag'}
plt.rc('font', **font)

plt.rcParams["figure.figsize"] = [20, 12]
plt.rcParams['font.size'] = 20 #フォントサイズを設定 default : 12
plt.rcParams['xtick.labelsize'] = 15 # 横軸のフォントサイズ
plt.rcParams['ytick.labelsize'] = 15

# test
df = pd.DataFrame(np.arange(0, 12).reshape(6, -1), columns = ['始め','終わり'])
df.plot(kind = 'bar', x = '始め', y = '終わり').set(xlabel = '始め', ylabel = '終わり')
# plt.show()  # %matplotlib inlineを指定しているため、あってもなくても良い
# Out:
# [Text(0,0.5,'終わり'), Text(0.5,0,'始め')]
# /anaconda3/envs/JohnsonJohnson/lib/python3.6/site-packages/matplotlib/font_manager.py:1341: UserWarning: findfont: Font family ['ipag'] not found. Falling back to DejaVu Sans
#   'findfont: Could not match %s. Returning %s' %

# %% [markdown]
# # Directory of font

# %%
import matplotlib as mpl
print(mpl.matplotlib_fname())
# Out:
# /anaconda3/envs/JohnsonJohnson/lib/python3.6/site-packages/matplotlib/mpl-data/matplotlibrc

# %%
import os

from matplotlib.font_manager import FontProperties
fp = FontProperties(fname=r'/Users/aa373282/Documents/Python/ProjectJJ/ipagp.ttf', size=14)

plt.bar([1, 2], [5, 10], 0.25)
plt.bar([1.25, 2.25], [4, 8], 0.25, color='darkorange')
plt.xlim((0.75, 2.75))
plt.ylim((0, 12))
plt.ylabel(u'軸ラベルはfontproperties=fp', fontproperties=fp)
plt.xticks([1.25, 2.25], [u'目盛りは', 'fontproperties=fp'], fontproperties=fp)
plt.title(u'タイトルはfontproperties=fp', fontproperties=fp)
plt.text(2.125, 10, u'テキストは\nfontproperties=fp', fontproperties=fp,
         ha='center')
plt.annotate(u'アノテーションは\nfontproperties=fp', xy=(1.125, 5), xytext=(1.3, 8),
             fontproperties=fp, arrowprops=dict(facecolor='k', shrink=0.05))
plt.legend([u'凡例は', 'prop=fp'], prop=fp, loc='upper left')
# plt.show()
plt.savefig('fontproperties.png', bbox_inches='tight')
# Out:
# /anaconda3/envs/JohnsonJohnson/lib/python3.6/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['IPAPGothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import matplotlib as plt
import matplotlib.font_manager as fm
import pandas as pd
fonts = fm.findSystemFonts()
fonts
# l = []
for f in fonts[-1:0:-1]:
    font = fm.FontProperties(fname=f)
    print("f=", f)
    print("font_name=", font.get_name())
    print("font_family=", font.get_family())
#     l.append((f, font.get_name(), font.get_family()))
# df = pd.DataFrame(l, columns=['path', 'name', 'family'])
# df[df['path'].apply(lambda s: 'IPA' in s)]

# plt.rcParams["font.family"] = "sans-serif"
# plt.rcParams["font.name"] = "IPAGothic"

# plt.rc('font', family='sans-serif') 
# plt.rc('font', serif='IPAGothic')
# Out:
# f= /Library/Fonts/STIXIntUpDReg.otf
# font_name= STIXIntegralsUpD
# font_family= ['sans-serif']
# f= /Library/Fonts/STIXSizOneSymBol.otf
# font_name= STIXSizeOneSym
# font_family= ['sans-serif']
# f= /Library/Fonts/STIXSizThreeSymBol.otf
# font_name= STIXSizeThreeSym
# font_family= ['sans-serif']
# f= /Library/Fonts/Managed/IBMPlexMono-Thin_3868686554.otf
# font_name= IBM Plex Mono
# font_family= ['sans-serif']
# f= /Library/Fonts/Arial Unicode.ttf
# font_name= Arial Unicode MS
# font_family= ['sans-serif']
# f= /Library/Fonts/STIXIntUpSmReg.otf
# font_name= STIXIntegralsUpSm
# font_family= ['sans-serif']
# f= /System/Library/Fonts/SFNSDisplay.ttf
# font_name= System Font
# font_family= ['sans-serif']
# f= /Library/Fonts/Managed/IBMPlexMono_714964245.otf
# font_name= IBM Plex Mono
# font_family= ['sans-serif']
# f= /System/Library/Fonts/SFCompactText-MediumItalic.otf
# font_name= .SF Compact Text
# font_family= ['sans-serif']
# f= /Library/Fonts/STIXSizFiveSymReg.otf
# ...

# %%
fonts
# Out:
# ['/System/Library/Fonts/SFNSDisplay-LightItalic.otf',
#  '/Library/Fonts/Managed/IBMPlexSans-Text_1598841832.otf',
#  '/Library/Fonts/STIXIntUpBol.otf',
#  '/System/Library/Fonts/SFNSDisplayCondensed-Heavy.otf',
#  '/Library/Fonts/STIXGeneral.otf',
#  '/Library/Fonts/Trebuchet MS Bold.ttf',
#  '/Library/Fonts/Managed/IBMPlexSerif-ExtraLight_1274106538.otf',
#  '/System/Library/Fonts/SFNSDisplay.ttf',
#  '/Library/Fonts/ipamp.ttf',
#  '/Library/Fonts/Managed/IBMPlexMono-Thin_3868686554.otf',
#  '/Library/Fonts/Arial Black.ttf',
#  '/Library/Fonts/STIXIntDBol.otf',
#  '/Library/Fonts/STIXIntUpSmBol.otf',
#  '/Library/Fonts/Verdana.ttf',
#  '/Library/Fonts/Managed/IBMPlexSerif-SemiBold_815118523.otf',
#  '/System/Library/Fonts/SFCompactDisplay-Heavy.otf',
#  '/System/Library/Fonts/SFNSSymbols-Regular.otf',
#  '/Library/Fonts/Courier New.ttf',
#  '/Library/Fonts/Trebuchet MS.ttf',
#  '/Library/Fonts/Gurmukhi.ttf',
#  '/Library/Fonts/Herculanum.ttf',
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

# plt.rc('font', family='sans-serif') 
# #plt.rc('font', serif='IPAGothic') 
# #plt.rc('font', serif='IPAPGothic') 
# #plt.rc('font', serif='IPAMincho') 
 plt.rc('font', serif='IPAexGothic') 

# plt.rc('font', **font)
    
plt.plot([20, 10], label="源清ければ流れ清し")
plt.title("難しい漢字も表示できるようになる")
plt.ylabel("九仞の功を一簣に虧く")
plt.xlabel("衣食足りて即ち栄辱を知る")
plt.legend()
plt.show()
# Out:
#   File "<ipython-input-5-8a16f5a82647>", line 8
#     plt.rc('font', serif='IPAexGothic')
#     ^
# IndentationError: unexpected indent
